# %% [markdown]
# ## What is Generative AI

# %% [markdown]
# Generative Al generate new data based on training sample.Generative model can
# generate Image,Text, Audio, Videos etc. data as output.
# So generative Al is a very huge topics,
# - Generative Image model
# - Generative Language model

# %% [markdown]
# Why are generative models required?
# - Understand Complex Pattern from Data
# - Content generation
# - Build Powerful Application

# %% [markdown]
# - Where Generative AI Exists Artificial Intelligence Machine Learning Deep Learning • Machine Learning is the subset of Artificial Intelligence • Deep Learning is the subset of Machine Learning • Generative Al is the subset of Deep Learning Generative Al
#
#
# - Discriminative vs Generative Model

# %% [markdown]
# Unsupervised Learning
# Supervised Learning
# Clustering:
# •
# K-Means
# DBScan
# Classification & Regression:

# %% [markdown]
# What is LIMs?
# Large Language Models (LLMs) are foundational machine learning models that use deep learning
# algorithms to process and understand natural language. These models are trained on massive amounts
# of text data to learn patterns and entity relationships in the language.
# It is a language model which is responsible for performing task such as text to text generation, text to
# image generation and image to text generations.

# %% [markdown]
# What makes ILM so Powerful?
# • In case of LLM, one model can be used for a whole variety of tasks like:-
# Text generation, Chatbot, summarizer, translation, code generation
# & so on ...
# So, LLM is subset of Deep Learning & it has some properties merge with
# Generative Al

# %% [markdown]
# End to end Generative Al Pipeline
# Generative Al pipeline is a set of steps followed to build an end to end GenAl
# software
# Break the problem down into several sub-problems, then try to develop a step-by-step
# procedure to solve them. Since language processing is involved, we would also list all
# the forms of text processing needed at each step. This step-by-step processing of text is
# known as a pipeline.

# %% [markdown]
# Generative Al Pipeline
# • Data acquisition
# • Data Preparation
# • Feature engineering
# Modeling
# • Evaluation
# • Deployment
# Monitoring and model updating

# %% [markdown]
# ### NLP Pipeline
#
# 1. Data Acquisition

# %% [markdown]
# - Available Data (csv, txt, pdf, doc, xlsx)
# - Other data (DB, internet, API, Scrapping)
# - no data - Create your own data with llms like OpenAI API
#
# Note: if you have a less data, then you can perform Data Augmmentation
#
# Example:
#
# 1. Replace with synonyms
# - I am a Data scientist Engineer
# - I am an AI engineer
#
# 2. biagram flip
# - my name is pratham
# - pratham is my name
#
# 3. Back transilate:
# 4. Add Additional Data/Noise

# %% [markdown]
# 2. Data preprocessing
#
# 1. cleanup: HIML, emo, spelling connection
# 2. Basic preprocessing
# 3. Advance prepocessing
#
#
# Basic preprocessing
# → tokenization - senetense and words
#
# - optional Proprocessing
# 1. stop word removal
# 2. streaming -  less used
# 3. lamitization - more used
# 4. punctuation removal
# 5. lower case
# 6. languagse detection
#
#
#
# ["My", "name", "is", "pratham"] - word level tokenisation
# sentense level tokenisation
#
# stimming operation in models so that they will not confuse
#
# lowercase operation in

# %% [markdown]
# Advance proprocessing
#
# Input:
#
# - parts of speech tagging POS tagging
# - Parse tree parsing
# - coference resolution
# -

# %% [markdown]
# ## Feature Engineering
#
# Text vecotorization
# - TFIDF
# - Bag of word
# - word to weight
# - one
# - Transformer model

# %% [markdown]
# ## modelling:
#
# - choose models (open source LLM, Paid model )
# -

# %% [markdown]
# ## Evaluation:
# - Intrinsive -> metrics -> Gen AI engineer
# - Extensive -> Deployment ->
#
# ## Deployement
# - Monitoring
# - Retranning

# %% [markdown]
# ## Common Terms
#
# Image augmentation artificially expands dataset diversity by applying transformations to existing training images (e.g., flipping, rotating, color-shifting). It is highly effective for preventing model overfitting and ensuring your computer vision model generalizes well in real-world scenarios.
#
# - Corpus (entire text)
# - Vocabulary (uniquey word)
# - Documents (one line or row)
# - word (single word)
# -

# %% [markdown]
# ## Data Representation and Data vectorization

# %% [markdown]
# - What is Feature extraction for text and image ?
# - Why we need it ?
# - Why its is so Difficult
# - What is the pros and cons
# - some techniques
#
# In Machine Learning, Tabular Data, CSV, XLSX
