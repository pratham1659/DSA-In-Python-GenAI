# %% [markdown]
# # Operators in Python

# %%
# Square Root Operators
import math
x = 5
print(x ** 3)
# Out:
# 125

# %%
a = 10
b = 10
x = a + 3
y = b - 3
print(x, y)
# Out:
# 13 7

# %%
# Augmented Operators
a = 10
b = 10
a += 3
b -= 3
print(a, b)
# Out:
# 13 7

# %%
# Arithmetic Operators
#  + - * % ** ^ -- +++

a = 10
b = 5
add = a+b #adding int and float type;returns a float number
mul = a*b
div = a/b
exp = a**b    # a to the power of b
concat = str(a) +'!'
mul_string = b*3
print(add,mul,div,exp,concat,mul_string)
# Out:
# 15 50 2.0 100000 10! 15

# %% [markdown]
# # operators precedence
# * parenthesis (), {},  []
# * Exponentials 2 ** 3
# * mulitplication or divison 2 * 3 or 2 / 3
# * Addition or Subtraction 2+3 or 3-4

# %%
## Operators precedence
num1 = 10 + 3 * 2
num2 = (2+3) * 10-3
print(num1)
print(num2)
# Out:
# 16
# 47

# %%
# Math Operators Rounding Numbers
import math
mth1 = 2.6  # 0.0 to 0.5 = 2
mth2 = 2.9  # 0.6 to 0.9 = 3
mth3 = "we"
print(round(mth1))
print(round(mth2))
print(abs(-2.4))  # print positive numbers
# Out:
# 3
# 3
# 2.4

# %%
print(math.ceil(2.9))
print(math.ceil(2.2))
print(math.floor(2.9))
print(math.floor(2.2))
# Out:
# 3
# 3
# 2
# 2

# %% [markdown]
# ## Logical Operators

# %%
#logical operations returns boolean
a = 5
b= 2
print(a==b , a>b, a<b , a!=b , a>=b , a<=b)
# Out:
# False True False True True False

# %%
#taking input from user
x = input("Enter a number: \n")
print(f"value entered {x}")
# Out:
# Enter a number:
# 23
# value entered 23

# %% [markdown]
# # Membership and Identity operators

# %%
#'in' operator
list1=[1,2,3,4,5] 
list2=[6,7,8,9] 
for item in list1: 
    if item in list2: 
        print("overlapping")
    else:
        print("Don`t Overlapping")
# Out:
# Don`t Overlapping
# Don`t Overlapping
# Don`t Overlapping
# Don`t Overlapping
# Don`t Overlapping

# %%
#'not in' operator
y = 20
list = [10, 20, 30, 40, 50 ]; 
  
if ( x not in list ): 
   print("x is NOT present in given list")
# Out:
# x is NOT present in given list

# %% [markdown]
# Identity operator are used to determine whether a value is of a certain class or type. They are usually used to determine the type of data a certain variable contains.

# %%
#'is' operator
x = 5
if (type(x) is int): 
    print("true") 
else: 
    print("false")
# Out:
# true

# %%
#'is not' operator
x = 5.2
if (type(x) is not int): 
    print("true") 
else: 
    print("false")
# Out:
# true
