# %% [markdown]
# # Dictionary in Python

# %%
# Dictinary is nothing but key value pairs
d1 = {}
print(type(d1))
d2 = {"Harry": "Burger",
      "Pratham": "Roti",
      "Rohan": "Chicken",
     "2": "Python",
     "3": "Machine Learning",
     "4": "Java"}
#   "Sam": {"B": "Mabbie", "L": "Roti", "D": "Rice"
print(d2)
# Out:
# <class 'dict'>
# {'Harry': 'Burger', 'Pratham': 'Roti', 'Rohan': 'Chicken', '2': 'Python', '3': 'Machine Learning', '4': 'Java'}

# %%
d2["3"]
# Out:
# 'Machine Learning'

# %%
d2["Rohan"]
# Out:
# 'Chicken'

# %%
d2["3"] = "JavaScript"
print(d2)
# Out:
# {'Harry': 'Burger', 'Pratham': 'Roti', 'Rohan': 'Chicken', '2': 'Python', '3': 'JavaScript', '4': 'Java'}

# %%
d1 = {
    "1": {"B": "Mabbie", "L": "Roti", "D": "Rice"},
    "2": "JavaScript",
    "3": "Python",
    "4": "Machine Learning"
}
print(d1)
# Out:
# {'1': {'B': 'Mabbie', 'L': 'Roti', 'D': 'Rice'}, '2': 'JavaScript', '3': 'Python', '4': 'Machine Learning'}

# %%
d2 = {
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"
}
d2["2"] = "Junk Food"
d2["3"] = "Pizza Food"
del d2["2"] #remove 2
# Print(d2[""])
print(d2)
# Out:
# {'1': 'JavaScript', '3': 'Pizza Food'}

# %%
d2 = {
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"
}
d3 = d2.copy()
del d3["3"]
print(d2)
print(d2.get("3"))
# Out:
# {'1': 'JavaScript', '2': 'Python', '3': 'Machine Learning'}
# Machine Learning

# %%
d2 = {
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"
}
d2.update({"3": "Oneplus"}) #changing values
print(d2)
# Out:
# {'1': 'JavaScript', '2': 'Python', '3': 'Oneplus'}

# %%
d2 = {
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"
}
print(d2.keys())  # keys for dictionary
print(d2.items())  # items for dictionary
# Out:
# dict_keys(['1', '2', '3'])
# dict_items([('1', 'JavaScript'), ('2', 'Python'), ('3', 'Machine Learning')])

# %%
Dict = {
    "harry": "Code",
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"}
key = input("Type key for Dict : ")
print(Dict[key])
# Out:
# Type key for Dict : 3
# Machine Learning

# %%
Dict = {
    "harry": "Code",
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"}

#looping through dictionary
for x in Dict:
  print(x)
# Out:
# harry
# 1
# 2
# 3

# %%
Dict = {
    "harry": "Code",
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"}

#or
for x in Dict.values():   #looping using the dict. values
  print(x)
# Out:
# Code
# JavaScript
# Python
# Machine Learning

# %%
thisdict = {
    "harry": "Code",
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"}

for key, value in Dict.items():   #looping using key and value
  print(key, value)
# Out:
# harry Code
# 1 JavaScript
# 2 Python
# 3 This is Adding in dictionary

# %%
#check if a key exists
if "harry" in thisdict:   #using membership operator 'in'
  print("Yes, 'model' is one of the keys in the thisdict dictionary")
# Out:
# Yes, 'model' is one of the keys in the thisdict dictionary

# %%
#adding items to dictionary

thisdict["3"] = "This is Adding in dictionary"
print(thisdict)
# Out:
# {'harry': 'Code', '1': 'JavaScript', '2': 'Python', '3': 'This is Adding in dictionary'}

# %%
#removing items
thisdict.pop("1")  #using pop() method
print(thisdict)
# Out:
# {'harry': 'Code', '2': 'Python', '3': 'This is Adding in dictionary'}

# %%
thisdict = {
    "harry": "Code",
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"}

thisdict.popitem()    #popitem() removes the last inserted item from the dictionary;in versions before 3.7 , it removes a random item
print(thisdict)
# Out:
# {'harry': 'Code', '1': 'JavaScript', '2': 'Python'}

# %%
thisdict = {
    "harry": "Code",
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"}

thisdict.clear()   #clear method clears the dictionary
print(thisdict)
# Out:
# {}

# %%
thisdict = {
    "harry": "Code",
    "1": "JavaScript",
    "2": "Python",
    "3": "Machine Learning"}

#del can also delete the complete dictionary
del thisdict
print(thisdict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0w/0_6r4jb118g0xffqd7ggz_yc0000gn/T/ipykernel_2498/1566338036.py in <module>
#       7 #del can also delete the complete dictionary
#       8 del thisdict
# ----> 9 print(thisdict)
#
# NameError: name 'thisdict' is not defined

# %% [markdown]
# # Dictionary methods
# * clear()-	Removes all the elements from the dictionary
#
# * copy()-	Returns a copy of the dictionary
#
# * fromkeys()-	Returns a dictionary with the specified keys and value
#
# * get()-	Returns the value of the specified key
#
# * items()-	Returns a list containing a tuple for each key value pair
#
# * keys()-	Returns a list containing the dictionary's keys
#
# * pop()-	Removes the element with the specified key
#
# * popitem()-	Removes the last inserted key-value pair
#
# * setdefault()-	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
#
# * update()-	Updates the dictionary with the specified key-value pairs
#
# * values()-	Returns a list of all the values in the dictionary
