# %%
n = 3  # Number of rows

for i in range(1, n + 1):
    spaces = n - i
    stars = i
    print(" " * spaces + "*" * stars)
# Out:
#   *
#  **
# ***

# %%
n = 3  # Number of rows

for i in range(1, n + 1):
    spaces = n - i
    stars = i
    pattern_line = " " * spaces + "*" * stars
    print(pattern_line)
# Out:
#   *
#  **
# ***

# %%
n=int(input("enter no of digits"))
for c in range(1,n+1):
	print(c)
# Out:
# 1
# 2
# 3
# 4
