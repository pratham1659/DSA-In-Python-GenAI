# %%
Welcome to Data Visualization Tool! This script is designed to help you visualize your data in various formats. You can input your dataset, choose the type of visualization you want, and customize it according to your needs.
