# %% [markdown]
# # **Installing and importing packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#installing a Package
# !pip install bokeh        #for example

# %% [markdown]
# # Python basic operations

# %%
print("hello Python")
# Out:
# hello Python

# %%
name = input("What is Your Name ")
color = input("What is your favourite color ")
print("Hi " + name)
print(name + " Likes " + color)
# Out:
# Hi Pratham
# Pratham Likes red

# %% [markdown]
# # Type Conversion

# %%
y = "Rohan"
x = 10

x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 y = "Rohan"
#       2 x = 10
# ----> 4 x + y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(x) + y
# Out:
# '10Rohan'

# %% [markdown]
# # Type Conversion

# %%
# This is Typecasting
birth_year = input("write your birth Year : ")
age = 2022 - int(birth_year)
print(age)
# Out:
# 1999

# %%
a=2
f=float(a)
print("Integer a =", a )
print("float a =", f )
l = [1,3,3,4,5]
s= set(l)
print(s)
print(l)
var1 = "20" #String integer Typecasting
var2 = "30" #String Typecasting
print(10 * str(int(var1) + int(var2)), " ")
# Out:
# Integer a = 2
# float a = 2.0
# {1, 3, 4, 5}
# [1, 3, 3, 4, 5]
# 50505050505050505050

# %%
weight_lbs = input("weight in LBS ")
weight_kg = int(weight_lbs) * 0.45
print(weight_kg)
# Out:
# weight in LBS 45
# 20.25

# %%
course1 = "Python's for Beginners"
course2 = 'Python for "Beginners"'
print(course1, "\n", course2)
# Out:
# Python's for Beginners
#  Python for "Beginners"

# %%
print("Hello World")
print(1+2)
# Out:
# Hello World
# 3

# %% [markdown]
# ### Escape Sequence Character

# %%
"""
This 
is
multiple 
comments
"""
print("hello Python")
print("hello \n pratham") #Escape Sequences Charcter //New Line Character
print("hello \ Pratham  \t Good Boy") # New Tab character

# %%
print("Additon Example")
a = 10
b = 30
print(a+b)
# Out:
# Additon Example
# 40

# %% [markdown]
# ### IndentationError

# %%
print("Additon Example")
    a = 10
b = 30
print(a+b)
# Out:
#   File "/var/folders/0w/0_6r4jb118g0xffqd7ggz_yc0000gn/T/ipykernel_2527/221933812.py", line 2
#     a = 10
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Single Line Comment

# %%
# Adding 2 variable in Printing the results in a new variable
a = 2
b = 3
c =a+b
print(c)
# Out:
# 5

# %% [markdown]
# ## Multi-Line Comment

# %%
var1 = "Hello print"
var2 = "43"
var22 = "34"
# var2 = 34
var3 = 34.6
var4 = 34424

print(type(var3))
print (var3 + var4) #TypeError: cannot concatenate 'str' and 'int' objects
print(100 * int(var22) + var3) ## TypeCasting in python.

# # print(100 * "Hello_World\n")  
print(100 * str(int(var2) + int(var22)))
# Out:
# <class 'float'>
# 34458.6
# 3434.6
# 77777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777777

# %% [markdown]
# # Docstring Comment

# %%
"""
docstring are not omitted by the interpreter comments are omitted
"""

# %% [markdown]
# # Classes and Objects

# %%
# Python3 program to
# demonstrate instantiating
# a class
class Car:
    # A simple class
    # attribute
    attr1 = "Petrol"
    attr2 = "750 HP"
    # A sample method 
    def start(self):
        print("Engine Started : Engine Type ", self.attr1)
        print("Ready to GO : Horse Power ", self.attr2)
# Driver code
# Object instantiation
BMW = Car()
# Accessing class attributes
# and method through objects
print(BMW.attr1)
BMW.start()
# Out:
# Petrol
# Engine Started : Engine Type  Petrol
# Ready to GO : Horse Power  750 HP

# %%
class Person:
    # init method or constructor 
    def __init__(self, name):
        self.name = name
    # Sample Method 
    def say_hi(self):
        print('Hello, my name is', self.name)
p = Person('Robert')
p.say_hi()
